# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt # the tidy way
import numpy as np

# %%
# 1D plotting
x = np.linspace(0, 3, 20)
y = np.linspace(0, 9, 20)
plt.plot(x, y)
plt.plot(x, y, 'o')
plt.show()

# %%
y = np.linspace(0, 9, 20)
y
# Out:
# array([0.        , 0.47368421, 0.94736842, 1.42105263, 1.89473684,
#        2.36842105, 2.84210526, 3.31578947, 3.78947368, 4.26315789,
#        4.73684211, 5.21052632, 5.68421053, 6.15789474, 6.63157895,
#        7.10526316, 7.57894737, 8.05263158, 8.52631579, 9.        ])

# %%
# 2D plottting
rng = np.random.default_rng(27446968)
image = rng.random((30, 30))
plt.imshow(image, cmap=plt.cm.hot)
plt.colorbar()

# %%
# Using heatmap to visualize a correclation matrix in python
import numpy as np
import matplotlib.pyplot as plt

# Example data: Randomly generated correlation matrix
data = np.random.random((10, 10))
correlation_matrix = np.corrcoef(data)
plt.imshow(correlation_matrix, cmap=plt.cm.hot, interpolation='nearest')
plt.colorbar()
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
# A 2D Matrix HeatMap
# Generate a random 2D matrix
rng = np.random.default_rng(27446968)
matrix = rng.random((10, 10))

# Plot the 2D matrix
plt.figure(figsize=(5, 6))
plt.imshow(matrix, cmap="viridis", interpolation='nearest')
plt.colorbar()
plt.title('2D Matrix Heatmap')
plt.show()

# %%
# Cosine function as a function of time

# Generate time values
time = np.linspace(0, 2 * np.pi, 1000)

# Compute the cosine of time
cosine_values = np.cos(time)

plt.figure(figsize=(10, 4))
plt.plot(time, cosine_values, label='cos(t)')
plt.title('Cosine Function')
plt.xlabel('Time')
plt.ylabel('cos(t)')
plt.legend()
plt.grid(True)
plt.show()
